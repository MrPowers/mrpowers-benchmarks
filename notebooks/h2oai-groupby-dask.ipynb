# %% [markdown]
# # h2oai groupby benchmarks

# %%
import dask.dataframe as dd

import pandas as pd

# %%
client.restart()
# Out:
# <Client: 'tcp://127.0.0.1:52237' processes=0 threads=0, memory=0 B>

# %%
# group_by_1e7_csv = "../data/h2o/groupby-datagen_1e7_1e2_0_0/csv/G1_1e7_1e2_0_0.csv"
# group_by_1e7_csv = "../data/mrpowers-h2o/groupby-1e7/*.csv"
group_by_1e7_parquet =  "../data/mrpowers-h2o/groupby-1e8/parquet"

# %%
x = dd.read_csv(
    group_by_1e7_csv,
    dtype={
        "id1": "category",
        "id2": "category",
        "id3": "category",
        "id4": "Int32",
        "id5": "Int32",
        "id6": "Int32",
        "v1": "Int32",
        "v2": "Int32",
        "v3": "float64",
    },
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 x = dd.read_csv(
#       2     group_by_1e7_csv,
#       3     dtype={
#       4         "id1": "category",
#       5         "id2": "category",
#       6         "id3": "category",
#       7         "id4": "Int32",
#       8         "id5": "Int32",
#       9         "id6": "Int32",
#      10         "v1": "Int32",
#      11         "v2": "Int32",
#      12         "v3": "float64",
#      13     },
#      14 )
#
# File ~/opt/miniconda3/envs/standard-coiled/lib/python3.9/site-packages/dask/dataframe/io/csv.py:742, in make_reader.<locals>.read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     729 def read(
#     730     urlpath,
#     731     blocksize="default",
#    (...)
#     740     **kwargs,
#     741 ):
# --> 742     return read_pandas(
#     743         reader,
#     744         urlpath,
#     745         blocksize=blocksize,
#     746         lineterminator=lineterminator,
#     747         compression=compression,
#     748         sample=sample,
#     749         sample_rows=sample_rows,
#     750         enforce=enforce,
#     751         assume_missing=assume_missing,
#     752         storage_options=storage_options,
#     753         include_path_column=include_path_column,
#     754         **kwargs,
#     755     )
#
# File ~/opt/miniconda3/envs/standard-coiled/lib/python3.9/site-packages/dask/dataframe/io/csv.py:521, in read_pandas(reader, urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     516     paths = get_fs_token_paths(urlpath, mode="rb", storage_options=storage_options)[
#     517         2
#     518     ]
#     520     # Infer compression from first path
# --> 521     compression = infer_compression(paths[0])
#     523 if blocksize == "default":
#     524     blocksize = AUTO_BLOCKSIZE
#
# IndexError: list index out of range

# %%
print(x.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 print(x.head())
#
# NameError: name 'x' is not defined

# %%
len(x)
# Out:
# 10000000

# %%
x.npartitions
# Out:
# 8

# %%
x.memory_usage(deep=True).compute()
# Out:
# Index         1024
# id1       10082944
# id2       10082944
# id3      112108332
# id4       50000000
# id5       50000000
# id6       50000000
# v1        50000000
# v2        50000000
# v3        80000000
# dtype: int64

# %% [markdown]
# ## q1: sum v1 by id1

# %%
# %%time
x.groupby("id1", dropna=False, observed=True).agg({"v1": "sum"}).compute()
# Out:
# CPU times: user 35.1 s, sys: 1.71 s, total: 36.8 s
# Wall time: 30.6 s
#            v1
# id1
# id001  299643
# id002  300028
# id003  299721
# id004  300195
# id005  299787
# ...       ...
# id096  299806
# id097  299654
# id098  299342
# id099  299492
# id100  299274
#
# [100 rows x 1 columns]

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet, columns=["id1", "v1"]
)

# %%
# %%time
ddf.groupby("id1", dropna=False, observed=True).v1.sum().compute()
# Out:
# CPU times: user 853 ms, sys: 31.7 ms, total: 885 ms
# Wall time: 608 ms
# id1
# id001    300108
# id002    299519
# id003    299905
# id004    300091
# id005    300377
#           ...
# id096    300030
# id097    299485
# id098    299836
# id099    300838
# id100    300251
# Name: v1, Length: 100, dtype: int64

# %% [markdown]
# ## q2: sum v1 by id1:id2

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id1", "id2", "v1"],
)

# %%
# %%time
ddf.groupby(["id1", "id2"], dropna=False, observed=True).agg({"v1": "sum"}).compute()
# Out:
# CPU times: user 755 ms, sys: 305 ms, total: 1.06 s
# Wall time: 275 ms
#                v1
# id1   id2
# id016 id016  3072
#       id045  3160
#       id023  2931
#       id057  2984
#       id040  2770
# ...           ...
# id096 id028  3017
#       id082  3184
#       id065  3159
#       id013  2903
#       id089  3002
#
# [10000 rows x 1 columns]

# %%
# %%time
x.groupby(["id1", "id2"], dropna=False, observed=True).agg({"v1": "sum"}).compute()
# Out:
# CPU times: user 36.3 s, sys: 2.25 s, total: 38.6 s
# Wall time: 34.6 s
#                v1
# id1   id2
# id016 id016  3072
#       id045  3160
#       id023  2931
#       id057  2984
#       id040  2770
# ...           ...
# id096 id028  3017
#       id082  3184
#       id065  3159
#       id013  2903
#       id089  3002
#
# [10000 rows x 1 columns]

# %% [markdown]
# ## q3: sum v1 mean v3 by id3

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id3", "v1", "v3"],
)

# %%
ddf.head()
# Out:
#             id3  v1         v3
# 0  id0000802287   2  15.906312
# 1  id0000981486   4  82.271518
# 2  id0000067860   2  64.772575
# 3  id0000206971   4  76.636741
# 4  id0000005733   3  32.212553

# %%
ddf.npartitions
# Out:
# 300

# %%
dask.utils.format_bytes(ddf.memory_usage(deep=True).sum().compute())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 dask.utils.format_bytes(ddf.memory_usage(deep=True).sum().compute())
#
# NameError: name 'dask' is not defined

# %%
# %%time
ddf.groupby("id3", dropna=False, observed=True).agg(
    {"v1": "sum", "v3": "mean"}
).compute()
# Out:
# CPU times: user 3min 30s, sys: 4.71 s, total: 3min 35s
# Wall time: 2min 43s
#               v1         v3
# id3
# id0000000384   1  28.652025
# id0000000523   2  74.354958
# id0000000697   5  81.733157
# id0000000712   2  58.601111
# id0000000774   3  87.279146
# ...           ..        ...
# id0000086964   5  77.610357
# id0000089248   3  58.322869
# id0000091079   6  46.431561
# id0000091391   1   1.774250
# id0000092459   2  94.091950
#
# [989933 rows x 2 columns]

# %%
# %%time
ddf.groupby("id3", dropna=False, observed=True).agg(
    {"v1": "sum", "v3": "mean"}, split_out=10
).compute()
# Out:
# CPU times: user 4min 22s, sys: 3.69 s, total: 4min 26s
# Wall time: 3min 22s
#               v1         v3
# id3
# id0000000921   1  89.095209
# id0000000956   1  61.749974
# id0000001267   4  14.587455
# id0000001796   1  63.727630
# id0000001852   3   5.712066
# ...           ..        ...
# id0000056574  10  25.382495
# id0000062809   2  90.368180
# id0000073687   5  29.001929
# id0000076318   4  31.566153
# id0000091391   1   1.774250
#
# [989933 rows x 2 columns]

# %%
import dask.distributed

# %%
client = dask.distributed.Client()

# %%
# %%time
ddf.groupby("id3", dropna=False, observed=True, ).agg(
    {"v1": "sum", "v3": "mean"}, split_out=2
).compute()
# Out:
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.39 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.42 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.50 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.50 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.42 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.44 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.44 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.65 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.65 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.52 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.52 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.89 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.89 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.45 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.86 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.41 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.39 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.82 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.75 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.75 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.75 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.70 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.69 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.56 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.56 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.69 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.52 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.52 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.58 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 77% memory usage. Resuming worker. Process memory: 1.55 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.55 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.40 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.55 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.39 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.52 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.35 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.38 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.50 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.52 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.56 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.59 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.59 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.47 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.44 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.48 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.59 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.51 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.63 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.87 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.50 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.86 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.62 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.63 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.63 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.78 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.55 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.77 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.61 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.88 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.61 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.82 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 76% memory usage. Resuming worker. Process memory: 1.54 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.54 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.86 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.86 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.79 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.77 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.49 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.75 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.67 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.67 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.59 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.53 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 1.61 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.68 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.72 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.71 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.61 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.61 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 1.59 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.59 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.71 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.79 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Worker is at 84% memory usage. Pausing worker.  Process memory: 1.69 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.84 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.71 GiB -- Worker memory limit: 2.00 GiB
# ...
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.60 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.57 GiB -- Worker memory limit: 2.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 1.64 GiB -- Worker memory limit: 2.00 GiB

# %%
# %%time
x.groupby("id3", dropna=False, observed=True).agg({"v1": "sum", "v3": "mean"}).compute()
# Out:
# CPU times: user 37.1 s, sys: 2.01 s, total: 39.1 s
# Wall time: 34.4 s
#                v1         v3
# id3
# id0000042202  281  53.198223
# id0000029558  327  45.245052
# id0000071286  322  49.842035
# id0000015141  308  50.790698
# id0000011083  307  47.676258
# ...           ...        ...
# id0000009966  318  53.899987
# id0000064729  298  48.259954
# id0000084431  238  50.899993
# id0000089703  323  45.874188
# id0000063367  211  50.396047
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## q4: mean v1:v3 by id4

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id4", "v1", "v2", "v3"],
)

# %%
# %%time
ddf.groupby("id4", dropna=False, observed=True).agg(
    {"v1": "mean", "v2": "mean", "v3": "mean"}
).compute()
# Out:
# CPU times: user 573 ms, sys: 130 ms, total: 703 ms
# Wall time: 340 ms
#            v1        v2         v3
# id4
# 1    3.001875  7.995427  49.983907
# 2    2.998208  7.996927  49.841268
# 3     3.00001  7.998429  49.880546
# 4    3.005033  8.008521  50.053042
# 5    2.999491   8.01399  50.005535
# ..        ...       ...        ...
# 96   2.996474  7.983614  49.889232
# 97   2.995558  7.990926  50.038346
# 98   2.986841  8.012647  50.124801
# 99   2.999043   7.98188  49.944407
# 100   2.99702  8.019508  49.963454
#
# [100 rows x 3 columns]

# %%
# %%time
x.groupby("id4", dropna=False, observed=True).agg(
    {"v1": "mean", "v2": "mean", "v3": "mean"}
).compute()
# Out:
# CPU times: user 36.4 s, sys: 2.35 s, total: 38.8 s
# Wall time: 35.4 s
#            v1        v2         v3
# id4
# 1    3.001875  7.995427  49.983907
# 2    2.998208  7.996927  49.841268
# 3     3.00001  7.998429  49.880546
# 4    3.005033  8.008521  50.053042
# 5    2.999491   8.01399  50.005535
# ..        ...       ...        ...
# 96   2.996474  7.983614  49.889232
# 97   2.995558  7.990926  50.038346
# 98   2.986841  8.012647  50.124801
# 99   2.999043   7.98188  49.944407
# 100   2.99702  8.019508  49.963454
#
# [100 rows x 3 columns]

# %% [markdown]
# ## q5: sum v1:v3 by id6

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id6", "v1", "v2", "v3"],
)

# %%
# %%time
ddf.groupby("id6", dropna=False, observed=True).agg(
    {"v1": "sum", "v2": "sum", "v3": "sum"}
).compute()
# Out:
# CPU times: user 1.22 s, sys: 233 ms, total: 1.45 s
# Wall time: 555 ms
#          v1   v2           v3
# id6
# 1       278  759  4500.324131
# 2       296  803  5139.198430
# 3       233  622  4081.984864
# 4       282  877  5539.323994
# 5       267  705  3886.950520
# ...     ...  ...          ...
# 99996   339  977  5925.965188
# 99997   262  745  4610.177984
# 99998   333  759  5134.606333
# 99999   305  749  5034.354274
# 100000  274  806  4651.894027
#
# [100000 rows x 3 columns]

# %%
# %%time
x.groupby("id6", dropna=False, observed=True).agg(
    {"v1": "sum", "v2": "sum", "v3": "sum"}
).compute()
# Out:
# CPU times: user 36.3 s, sys: 1.66 s, total: 38 s
# Wall time: 32.7 s
#          v1   v2           v3
# id6
# 1       278  759  4500.324131
# 2       296  803  5139.198430
# 3       233  622  4081.984864
# 4       282  877  5539.323994
# 5       267  705  3886.950520
# ...     ...  ...          ...
# 99996   339  977  5925.965188
# 99997   262  745  4610.177984
# 99998   333  759  5134.606333
# 99999   305  749  5034.354274
# 100000  274  806  4651.894027
#
# [100000 rows x 3 columns]

# %% [markdown]
# ## q6: Intentionally skipped cause it's commented out

# %% [markdown]
# ## q7: max v1 - min v2 by id3

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id3", "v1", "v2"],
)

# %%
# %%time
ddf.groupby("id3", dropna=False, observed=True).agg({"v1": "max", "v2": "min"}).assign(
    range_v1_v2=lambda x: x["v1"] - x["v2"]
)[["range_v1_v2"]].compute()
# Out:
# CPU times: user 1.42 s, sys: 89 ms, total: 1.51 s
# Wall time: 1.12 s
#               range_v1_v2
# id3
# id0000042202            4
# id0000029558            4
# id0000071286            4
# id0000015141            4
# id0000011083            4
# ...                   ...
# id0000009966            4
# id0000064729            4
# id0000084431            4
# id0000089703            4
# id0000063367            4
#
# [100000 rows x 1 columns]

# %%
# %%time
x.groupby("id3", dropna=False, observed=True).agg({"v1": "max", "v2": "min"}).assign(
    range_v1_v2=lambda x: x["v1"] - x["v2"]
)[["range_v1_v2"]].compute()
# Out:
# CPU times: user 36.8 s, sys: 1.64 s, total: 38.4 s
# Wall time: 33.2 s
#               range_v1_v2
# id3
# id0000042202            4
# id0000029558            4
# id0000071286            4
# id0000015141            4
# id0000011083            4
# ...                   ...
# id0000009966            4
# id0000064729            4
# id0000084431            4
# id0000089703            4
# id0000063367            4
#
# [100000 rows x 1 columns]

# %% [markdown]
# ## q8: largest two v3 by id6

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id6", "v1", "v2", "v3"],
)

# %%
# %%time
ddf[~ddf["v3"].isna()][["id6", "v3"]].groupby("id6", dropna=False, observed=True).apply(
    lambda x: x.nlargest(2, columns="v3"), meta={"id6": "Int64", "v3": "float64"}
)[["v3"]].compute()
# Out:
# CPU times: user 2min 36s, sys: 12.6 s, total: 2min 49s
# Wall time: 2min 35s
#                       v3
# id6
# 9     708485   99.930063
#       1233683  99.920439
# 19    82918    97.625727
#       625200   97.036998
# 33    1183098  99.414996
# ...                  ...
# 99994 168013   96.185434
# 99998 136085   99.405711
#       197174   99.278838
# 99999 667180   99.555205
#       290571   97.386879
#
# [200000 rows x 1 columns]

# %%
# %%time
x[~x["v3"].isna()][["id6", "v3"]].groupby("id6", dropna=False, observed=True).apply(
    lambda x: x.nlargest(2, columns="v3"), meta={"id6": "Int64", "v3": "float64"}
)[["v3"]].compute()
# Out:
# CPU times: user 3min 12s, sys: 14.9 s, total: 3min 26s
# Wall time: 3min 9s
#                       v3
# id6
# 9     708485   99.930063
#       1233683  99.920439
# 19    82918    97.625727
#       625200   97.036998
# 33    1183098  99.414996
# ...                  ...
# 99994 168013   96.185434
# 99998 136085   99.405711
#       197174   99.278838
# 99999 667180   99.555205
#       290571   97.386879
#
# [200000 rows x 1 columns]

# %% [markdown]
# # q9: regression v1 v2 by id2 id4

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id2", "id4", "v1", "v2"],
)

# %%
# %%time
ddf[["id2", "id4", "v1", "v2"]].groupby(
    ["id2", "id4"], dropna=False, observed=True
).apply(
    lambda x: pd.Series({"r2": x.corr()["v1"]["v2"] ** 2}), meta={"r2": "float64"}
).compute()
# Out:
# CPU times: user 8.08 s, sys: 1.6 s, total: 9.68 s
# Wall time: 5.63 s
#                  r2
# id2   id4
# id041 3    0.000002
#       8    0.002711
#       24   0.000868
#       25   0.004970
#       37   0.000224
# ...             ...
# id001 35   0.000494
#       38   0.001098
#       59   0.000683
#       90   0.000092
#       92   0.000191
#
# [10000 rows x 1 columns]

# %%
# %%time
x[["id2", "id4", "v1", "v2"]].groupby(
    ["id2", "id4"], dropna=False, observed=True
).apply(
    lambda x: pd.Series({"r2": x.corr()["v1"]["v2"] ** 2}), meta={"r2": "float64"}
).compute()
# Out:
# CPU times: user 43.8 s, sys: 3.8 s, total: 47.6 s
# Wall time: 40 s
#                      r2
# id2   id4
# id047 3    3.313240e-05
#       8    7.364508e-04
#       24   2.032771e-03
#       25   2.191219e-04
#       37   2.745002e-04
# ...                 ...
# id018 35   8.950952e-07
#       38   2.433695e-05
#       59   9.727365e-05
#       90   1.466000e-04
#       92   6.965067e-04
#
# [10000 rows x 1 columns]

# %% [markdown]
# ## q10: sum v3 count by id1:id6

# %%
ddf = dd.read_parquet(
    group_by_1e7_parquet,
    columns=["id1", "id2", "id3", "id4", "id5", "id6", "v1", "v3"],
)

# %%
# %%time
ddf.groupby(["id1", "id2", "id3", "id4", "id5", "id6"], dropna=False, observed=True).agg(
    {"v3": "sum", "v1": "size"}
).compute()
# Out:
# CPU times: user 15.1 s, sys: 3.02 s, total: 18.1 s
# Wall time: 14.2 s
#                                                v3  v1
# id1   id2   id3          id4 id5 id6
# id016 id016 id0000042202 15  24  5971   37.211254   1
#             id0000096717 90  36  24881  68.265721   1
#             id0000050660 56  2   31346  69.197638   1
#             id0000006913 30  76  22749  60.054044   1
#             id0000032257 19  19  41901  71.002708   1
# ...                                           ...  ..
# id054 id002 id0000063962 43  67  18942  51.507418   1
#             id0000098794 99  100 27574  96.151364   1
#             id0000063695 6   90  7197    2.603732   1
#             id0000078453 2   42  53619  74.687472   1
#             id0000014636 83  71  67900   5.967089   1
#
# [10000000 rows x 2 columns]

# %%
# %%time
x.groupby(["id1", "id2", "id3", "id4", "id5", "id6"], dropna=False, observed=True).agg(
    {"v3": "sum", "v1": "size"}
).compute()
# Out:
# CPU times: user 51.2 s, sys: 5.15 s, total: 56.3 s
# Wall time: 49.1 s
#                                                v3  v1
# id1   id2   id3          id4 id5 id6
# id016 id016 id0000042202 15  24  5971   37.211254   1
#             id0000096717 90  36  24881  68.265721   1
#             id0000050660 56  2   31346  69.197638   1
#             id0000006913 30  76  22749  60.054044   1
#             id0000032257 19  19  41901  71.002708   1
# ...                                           ...  ..
# id054 id002 id0000063962 43  67  18942  51.507418   1
#             id0000098794 99  100 27574  96.151364   1
#             id0000063695 6   90  7197    2.603732   1
#             id0000078453 2   42  53619  74.687472   1
#             id0000014636 83  71  67900   5.967089   1
#
# [10000000 rows x 2 columns]
